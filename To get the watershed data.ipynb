# %% [markdown]
# Copyright Jana Schaich Borg/Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)

# %% [markdown]
# # How to Meet and Retrieve Your Data

# %% [markdown]
# Watershed's intern put together a couple of sources of information that will be useful for your project. These three types of information are contained in the capstone database:
# 1. the current monthly rent Watershed charges for all of their client’s 244 properties, as well as the property type and geographic location of those properties.
# 2. some general information about examples of short-term rental properties.  This information can be used to get a sense of what kind of nightly rental price Watershed’s client’s properties *could* be listed for, if they were converted to short-term rentals.
# 3. records about when those short-term rental properties were rented out, so that you can calculate their occupancy rates.

# %% [markdown]
# Your job is to determine how the database is organized so that you can retrieve all of the available information about Watershed’s client’s 244 properties, as well as the corresponding short-term rental information for comparable properties in the same location and of the same type.
# 1. Start by determining what tables the database contains, and what fields are included in each table.
# 2. Then, we recommend that you make at least a rough relational schema of how the database is organized, so that you know what fields you can use to join tables.
# 3. Next, make a list of the columns of data you want to retrieve in your final output.
# 4. Finally, write your query to retrieve the desired data from the database.

# %% [markdown]
# Here are some hints about how to write your query:
# * Start by joining no more than two tables.  After you have made sure the query works as written and that the output makes sense, add other tables one at a time, checking the new query and its results each time.
# * Your final output should have 244 rows.  Given the limited output, the easiest way to extract the results will be to copy and paste the output from your query into Excel, although you could also extract as a .csv file and open that with Excel.  If you choose the .csv option, you might find it necessary to write your query on multiple lines when you declare it as a variable.  To do this, type a space (if you forget the space the lines will run together) and a "\" at the end of each line of your query:
#
# ```
# my_data= %sql SELECT DISTINCT user_guid, state, membership_type \
# FROM users \
# WHERE country="US" AND state IS NOT NULL and membership_type IS NOT NULL \
# ORDER BY state ASC, membership_type ASC ;
#
# my_data.csv('my_data.csv')
# ```
#
# * We recommend that you calculate the occupancy rates of the example short-term rental properties within MySQL, rather than within Excel (it will be much faster!)  To do this, only examine rental dates during 2015, and remember that there are 365 days in the year.  The final output of your calculation should be the percentage of days in 2015 that the property was occupied.  You may want to consider using a subquery for this calculation.
# * Make sure that you extract information from short-term rentals <u>**_that have the same location and property type_**</u> as the 244 Watershed properties.
# * If you run into trouble, use your workbooks and Teradata notes from “Managing Big Data with MySQL” to remind you how to implement different parts of your query.
#
# <img src="https://duke.box.com/shared/static/svbdzasxe7nncnszps6ewnkr8og4798c.jpg" width="300" alt="SQL Master"/>

# %% [markdown]
# ## Good luck and have fun!

# %% [markdown]
# To get started, connect to the capstone database and set the database as your default database using the following commands:
#
# ```python
# %load_ext sql
# %sql mysql://studentuser:studentpw@mysqlserver/capstone
# %sql USE capstone
# ```

# %% [markdown]
# ### Load and connect to the database

# %%
# %load_ext sql
# %sql mysql://studentuser:studentpw@mysqlserver/capstone 
# %sql USE capstone
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 0 rows affected.
# []

# %%
# %%sql
# SELECT st_property, COUNT(DISTINCT rental_date)/365 AS occupy_rate
# FROM st_rental_dates
# WHERE rental_date > '2014-12-31' AND rental_date <= '2015-12-31'
# GROUP BY st_property;
# Out:
# 723 rows affected.
# [('ST1', Decimal('0.1616')),
#  ('ST10', Decimal('0.3479')),
#  ('ST100', Decimal('0.3973')),
#  ('ST1000', Decimal('0.9808')),
#  ('ST101', Decimal('0.3644')),
#  ('ST102', Decimal('0.4110')),
#  ('ST103', Decimal('0.4110')),
#  ('ST104', Decimal('0.5260')),
#  ('ST105', Decimal('0.4329')),
#  ('ST106', Decimal('0.6959')),
#  ('ST107', Decimal('0.1096')),
#  ('ST108', Decimal('0.2247')),
#  ('ST109', Decimal('0.2192')),
#  ('ST11', Decimal('0.3918')),
#  ('ST110', Decimal('0.5370')),
#  ('ST111', Decimal('0.5123')),
#  ('ST112', Decimal('0.3616')),
#  ('ST113', Decimal('0.8438')),
#  ('ST114', Decimal('0.9151')),
#  ('ST115', Decimal('0.4301')),
#  ('ST116', Decimal('0.4822')),
#  ('ST117', Decimal('0.4904')),
#  ('ST118', Decimal('0.5233')),
#  ('ST119', Decimal('0.4493')),
#  ('ST12', Decimal('0.6603')),
#  ('ST120', Decimal('0.4877')),
#  ('ST121', Decimal('0.4384')),
#  ('ST122', Decimal('0.5315')),
#  ('ST123', Decimal('0.1397')),
#  ('ST124', Decimal('0.4685')),
#  ('ST125', Decimal('0.5014')),
#  ('ST126', Decimal('0.3068')),
#  ('ST127', Decimal('0.5205')),
#  ('ST128', Decimal('0.1288')),
#  ('ST129', Decimal('0.2411')),
#  ('ST13', Decimal('0.4521')),
#  ('ST130', Decimal('0.4795')),
#  ('ST131', Decimal('0.2712')),
#  ('ST132', Decimal('0.4301')),
#  ('ST133', Decimal('0.5671')),
#  ('ST134', Decimal('0.3205')),
#  ('ST135', Decimal('0.4493')),
#  ('ST136', Decimal('0.5096')),
#  ('ST137', Decimal('0.7205')),
#  ('ST138', Decimal('0.4959')),
#  ('ST139', Decimal('0.4493')),
#  ('ST14', Decimal('0.5315')),
#  ('ST140', Decimal('0.1507')),
#  ('ST141', Decimal('0.6000')),
#  ('ST142', Decimal('0.5260')),
#  ('ST143', Decimal('0.2110')),
#  ('ST144', Decimal('0.3315')),
#  ('ST145', Decimal('0.3288')),
#  ('ST146', Decimal('0.6192')),
#  ('ST147', Decimal('0.2712')),
#  ('ST148', Decimal('0.3288')),
#  ('ST149', Decimal('0.4137')),
#  ('ST15', Decimal('0.4795')),
#  ('ST150', Decimal('0.6301')),
#  ('ST151', Decimal('0.9041')),
#  ('ST152', Decimal('0.5425')),
#  ('ST153', Decimal('0.0795')),
#  ('ST154', Decimal('0.5507')),
#  ('ST155', Decimal('0.6932')),
#  ('ST156', Decimal('0.7151')),
#  ('ST157', Decimal('0.5205')),
#  ('ST158', Decimal('0.1589')),
#  ('ST159', Decimal('0.5452')),
#  ('ST16', Decimal('0.4795')),
#  ('ST160', Decimal('0.5863')),
#  ('ST161', Decimal('0.6795')),
#  ('ST162', Decimal('0.5781')),
#  ('ST163', Decimal('0.4110')),
#  ('ST164', Decimal('0.6822')),
#  ('ST165', Decimal('0.8247')),
#  ('ST166', Decimal('0.2164')),
#  ('ST167', Decimal('0.6000')),
#  ('ST168', Decimal('0.3918')),
#  ('ST169', Decimal('0.5890')),
#  ('ST17', Decimal('0.2932')),
#  ('ST170', Decimal('0.2712')),
#  ('ST171', Decimal('0.5507')),
#  ('ST172', Decimal('0.4521')),
#  ('ST173', Decimal('0.5178')),
#  ('ST174', Decimal('0.5205')),
#  ('ST175', Decimal('0.6301')),
#  ('ST176', Decimal('0.3699')),
#  ('ST177', Decimal('0.5699')),
#  ('ST178', Decimal('0.4192')),
#  ('ST179', Decimal('0.4548')),
#  ('ST18', Decimal('0.6219')),
#  ('ST180', Decimal('0.7096')),
#  ('ST181', Decimal('0.3096')),
#  ('ST182', Decimal('0.2411')),
#  ('ST183', Decimal('0.0466')),
#  ('ST184', Decimal('0.6356')),
#  ('ST185', Decimal('0.4301')),
#  ('ST186', Decimal('0.3808')),
#  ('ST187', Decimal('0.4575')),
#  ('ST19', Decimal('0.2986')),
#  ('ST191', Decimal('0.3918')),
#  ('ST192', Decimal('0.3863')),
#  ('ST193', Decimal('0.4877')),
#  ('ST194', Decimal('0.4110')),
#  ('ST195', Decimal('0.5041')),
#  ('ST196', Decimal('0.2767')),
#  ('ST197', Decimal('0.3288')),
#  ('ST198', Decimal('0.5315')),
#  ('ST199', Decimal('0.4274')),
#  ('ST2', Decimal('0.2411')),
#  ('ST20', Decimal('0.4110')),
#  ('ST200', Decimal('0.3973')),
#  ('ST201', Decimal('0.7973')),
#  ('ST202', Decimal('0.6877')),
#  ('ST203', Decimal('0.5890')),
#  ('ST204', Decimal('0.6192')),
#  ('ST205', Decimal('0.4548')),
#  ('ST206', Decimal('0.4877')),
#  ('ST207', Decimal('0.4795')),
#  ('ST208', Decimal('0.4932')),
#  ('ST209', Decimal('0.3616')),
#  ('ST21', Decimal('0.4219')),
#  ('ST210', Decimal('0.7425')),
#  ('ST211', Decimal('0.3699')),
#  ('ST218', Decimal('0.2712')),
#  ('ST219', Decimal('0.7616')),
#  ('ST220', Decimal('0.6082')),
#  ('ST221', Decimal('0.6110')),
#  ('ST222', Decimal('0.3068')),
#  ('ST223', Decimal('0.5233')),
#  ('ST224', Decimal('0.4822')),
#  ('ST225', Decimal('0.2219')),
#  ('ST226', Decimal('0.3890')),
#  ('ST227', Decimal('0.4164')),
#  ('ST228', Decimal('0.4849')),
#  ('ST229', Decimal('0.5507')),
#  ('ST230', Decimal('0.2932')),
#  ('ST231', Decimal('0.5014')),
#  ('ST232', Decimal('0.3014')),
#  ('ST235', Decimal('0.4986')),
#  ('ST236', Decimal('0.6384')),
#  ('ST237', Decimal('0.2904')),
#  ('ST238', Decimal('0.5397')),
#  ('ST239', Decimal('0.2795')),
#  ('ST240', Decimal('0.3890')),
#  ('ST241', Decimal('0.5753')),
#  ('ST242', Decimal('0.3123')),
#  ('ST243', Decimal('0.4521')),
#  ('ST244', Decimal('0.5315')),
#  ('ST3', Decimal('0.3123')),
#  ('ST31', Decimal('0.6000')),
#  ('ST32', Decimal('0.2329')),
#  ('ST33', Decimal('0.4082')),
#  ('ST34', Decimal('0.3260')),
#  ('ST35', Decimal('0.3890')),
#  ('ST355', Decimal('0.2932')),
#  ('ST356', Decimal('0.6411')),
#  ('ST357', Decimal('0.5041')),
#  ('ST358', Decimal('0.4027')),
#  ('ST359', Decimal('0.5068')),
#  ('ST36', Decimal('0.5205')),
#  ('ST360', Decimal('0.3699')),
#  ('ST361', Decimal('0.2356')),
#  ('ST362', Decimal('0.5808')),
#  ('ST363', Decimal('0.0192')),
#  ('ST364', Decimal('0.4685')),
#  ('ST365', Decimal('0.3425')),
#  ('ST366', Decimal('0.2712')),
#  ('ST37', Decimal('0.4630')),
#  ('ST38', Decimal('0.6795')),
#  ('ST39', Decimal('0.6822')),
#  ('ST4', Decimal('0.5699')),
#  ('ST40', Decimal('0.8685')),
#  ('ST41', Decimal('0.5233')),
#  ('ST42', Decimal('0.4603')),
#  ('ST422', Decimal('0.5123')),
#  ('ST423', Decimal('0.8164')),
#  ('ST424', Decimal('0.6767')),
#  ('ST425', Decimal('0.5397')),
#  ('ST426', Decimal('0.4027')),
#  ('ST427', Decimal('0.4000')),
#  ('ST428', Decimal('0.4301')),
#  ('ST429', Decimal('0.4027')),
#  ('ST43', Decimal('0.3534')),
#  ('ST430', Decimal('0.2301')),
#  ('ST44', Decimal('0.4986')),
#  ('ST45', Decimal('0.5151')),
#  ('ST46', Decimal('0.8712')),
#  ('ST47', Decimal('0.5068')),
#  ('ST48', Decimal('0.2822')),
#  ('ST488', Decimal('0.1890')),
#  ('ST489', Decimal('0.2904')),
#  ('ST49', Decimal('0.5425')),
#  ('ST490', Decimal('0.5808')),
#  ('ST5', Decimal('0.0822')),
#  ('ST50', Decimal('0.3479')),
#  ('ST51', Decimal('0.4767')),
#  ('ST512', Decimal('0.4411')),
#  ('ST513', Decimal('0.4795')),
#  ('ST514', Decimal('0.4137')),
#  ('ST515', Decimal('0.4438')),
#  ('ST516', Decimal('0.6192')),
#  ('ST517', Decimal('0.5479')),
#  ('ST519', Decimal('0.3425')),
#  ('ST52', Decimal('0.7781')),
#  ('ST520', Decimal('0.6000')),
#  ('ST522', Decimal('0.9890')),
#  ('ST523', Decimal('0.9781')),
#  ('ST524', Decimal('0.9699')),
#  ('ST525', Decimal('0.9945')),
#  ('ST526', Decimal('0.9726')),
#  ('ST527', Decimal('0.9863')),
#  ('ST528', Decimal('0.9781')),
#  ('ST529', Decimal('0.9726')),
#  ('ST53', Decimal('0.3973')),
#  ('ST530', Decimal('0.9753')),
#  ('ST531', Decimal('0.9644')),
#  ('ST532', Decimal('0.9836')),
#  ('ST533', Decimal('0.9890')),
#  ('ST534', Decimal('0.9808')),
#  ('ST535', Decimal('0.9781')),
#  ('ST536', Decimal('0.9836')),
#  ('ST537', Decimal('0.9945')),
#  ('ST538', Decimal('0.9781')),
#  ('ST539', Decimal('0.9699')),
#  ('ST54', Decimal('0.6000')),
#  ('ST540', Decimal('0.9890')),
#  ('ST541', Decimal('0.9753')),
#  ('ST542', Decimal('0.9863')),
#  ('ST543', Decimal('0.9753')),
#  ('ST544', Decimal('0.9945')),
#  ('ST545', Decimal('0.9781')),
#  ('ST546', Decimal('0.9699')),
#  ('ST547', Decimal('0.9616')),
#  ('ST548', Decimal('0.9781')),
#  ('ST549', Decimal('0.9863')),
#  ('ST550', Decimal('0.9836')),
#  ('ST551', Decimal('0.9836')),
#  ('ST552', Decimal('0.9836')),
#  ('ST553', Decimal('0.9781')),
#  ('ST554', Decimal('0.9753')),
#  ('ST555', Decimal('0.9863')),
#  ('ST556', Decimal('0.9753')),
#  ('ST557', Decimal('0.9808')),
#  ('ST558', Decimal('0.9863')),
#  ('ST559', Decimal('0.9726')),
#  ('ST560', Decimal('0.9753')),
#  ('ST561', Decimal('0.9836')),
#  ('ST562', Decimal('0.9836')),
#  ('ST563', Decimal('0.9753')),
#  ('ST564', Decimal('0.9781')),
#  ('ST565', Decimal('0.9890')),
#  ('ST566', Decimal('0.9836')),
#  ('ST567', Decimal('0.9918')),
#  ('ST568', Decimal('0.9836')),
#  ('ST569', Decimal('0.9808')),
#  ('ST570', Decimal('0.9836')),
#  ('ST571', Decimal('0.9808')),
#  ('ST572', Decimal('0.9863')),
#  ('ST573', Decimal('0.9726')),
#  ('ST574', Decimal('0.9808')),
#  ('ST575', Decimal('0.9753')),
#  ('ST576', Decimal('0.9890')),
#  ('ST577', Decimal('0.9836')),
#  ('ST578', Decimal('0.9890')),
#  ('ST579', Decimal('0.9781')),
#  ('ST580', Decimal('0.9808')),
#  ('ST581', Decimal('0.9753')),
#  ('ST582', Decimal('0.9808')),
#  ('ST583', Decimal('0.9644')),
#  ('ST584', Decimal('0.9753')),
#  ('ST585', Decimal('0.9945')),
#  ('ST586', Decimal('0.9836')),
#  ('ST587', Decimal('0.9699')),
#  ('ST588', Decimal('0.9863')),
#  ('ST589', Decimal('0.9726')),
#  ('ST590', Decimal('0.9836')),
#  ('ST591', Decimal('0.9890')),
#  ('ST592', Decimal('0.9753')),
#  ('ST593', Decimal('0.9644')),
#  ('ST594', Decimal('0.9863')),
#  ('ST595', Decimal('0.9753')),
#  ('ST596', Decimal('0.9836')),
#  ('ST597', Decimal('0.9808')),
#  ('ST598', Decimal('0.9753')),
#  ('ST599', Decimal('0.9863')),
#  ('ST6', Decimal('0.5479')),
#  ('ST600', Decimal('0.9836')),
#  ('ST601', Decimal('0.9890')),
#  ('ST602', Decimal('0.9863')),
#  ('ST603', Decimal('0.9863')),
#  ('ST604', Decimal('0.9726')),
#  ('ST605', Decimal('0.9836')),
#  ('ST606', Decimal('0.9671')),
#  ('ST607', Decimal('0.9808')),
#  ('ST608', Decimal('0.9671')),
#  ('ST609', Decimal('0.9726')),
#  ('ST610', Decimal('0.9863')),
#  ('ST611', Decimal('0.9699')),
#  ('ST612', Decimal('0.9781')),
#  ('ST613', Decimal('0.9918')),
#  ('ST614', Decimal('0.9890')),
#  ('ST615', Decimal('0.9808')),
#  ('ST616', Decimal('0.9836')),
#  ('ST617', Decimal('0.9753')),
#  ('ST618', Decimal('0.9808')),
#  ('ST619', Decimal('0.9836')),
#  ('ST620', Decimal('0.9781')),
#  ('ST621', Decimal('0.9781')),
#  ('ST622', Decimal('0.9781')),
#  ('ST623', Decimal('0.9973')),
#  ('ST624', Decimal('0.9726')),
#  ('ST625', Decimal('0.9699')),
#  ('ST626', Decimal('0.9616')),
#  ('ST627', Decimal('0.9808')),
#  ('ST628', Decimal('0.9726')),
#  ('ST629', Decimal('0.9781')),
#  ('ST630', Decimal('0.9890')),
#  ('ST631', Decimal('0.9890')),
#  ('ST632', Decimal('0.9808')),
#  ('ST633', Decimal('0.9836')),
#  ('ST634', Decimal('0.9753')),
#  ('ST635', Decimal('0.9808')),
#  ('ST636', Decimal('0.9808')),
#  ('ST637', Decimal('0.9808')),
#  ('ST638', Decimal('0.9699')),
#  ('ST639', Decimal('0.9808')),
#  ('ST640', Decimal('0.9753')),
#  ('ST641', Decimal('0.9671')),
#  ('ST642', Decimal('0.9808')),
#  ('ST643', Decimal('0.9918')),
#  ('ST644', Decimal('0.9836')),
#  ('ST645', Decimal('0.9863')),
#  ('ST646', Decimal('0.9699')),
#  ('ST647', Decimal('0.9781')),
#  ('ST648', Decimal('0.9836')),
#  ('ST649', Decimal('0.9890')),
#  ('ST650', Decimal('0.9863')),
#  ('ST651', Decimal('0.9808')),
#  ('ST652', Decimal('0.9781')),
#  ('ST653', Decimal('0.9644')),
#  ('ST654', Decimal('0.9863')),
#  ('ST655', Decimal('0.9945')),
#  ('ST656', Decimal('0.9863')),
#  ('ST657', Decimal('0.9753')),
#  ('ST658', Decimal('0.9671')),
#  ('ST659', Decimal('0.9808')),
#  ('ST660', Decimal('0.9808')),
#  ('ST661', Decimal('0.9808')),
#  ('ST662', Decimal('0.9562')),
#  ('ST663', Decimal('0.9863')),
#  ('ST664', Decimal('0.9836')),
#  ('ST665', Decimal('0.9863')),
#  ('ST666', Decimal('0.9699')),
#  ('ST667', Decimal('0.9781')),
#  ('ST668', Decimal('0.9781')),
#  ('ST669', Decimal('0.9753')),
#  ('ST67', Decimal('0.4301')),
#  ('ST670', Decimal('0.9699')),
#  ('ST671', Decimal('0.9726')),
#  ('ST672', Decimal('0.9836')),
#  ('ST673', Decimal('0.9863')),
#  ('ST674', Decimal('0.9918')),
#  ('ST675', Decimal('0.9863')),
#  ('ST676', Decimal('0.9726')),
#  ('ST677', Decimal('0.9753')),
#  ('ST678', Decimal('0.9726')),
#  ('ST679', Decimal('0.9781')),
#  ('ST68', Decimal('0.6055')),
#  ('ST680', Decimal('0.9699')),
#  ('ST681', Decimal('0.9863')),
#  ('ST682', Decimal('0.9562')),
#  ('ST683', Decimal('0.9863')),
#  ('ST684', Decimal('0.9753')),
#  ('ST685', Decimal('0.9781')),
#  ('ST686', Decimal('0.9918')),
#  ('ST687', Decimal('0.9918')),
#  ('ST688', Decimal('0.9699')),
#  ('ST689', Decimal('0.9781')),
#  ('ST69', Decimal('0.5671')),
#  ('ST690', Decimal('0.9781')),
#  ('ST691', Decimal('0.9699')),
#  ('ST692', Decimal('0.9726')),
#  ('ST693', Decimal('0.9863')),
#  ('ST694', Decimal('0.9836')),
#  ('ST695', Decimal('0.9781')),
#  ('ST696', Decimal('0.9808')),
#  ('ST697', Decimal('0.9808')),
#  ('ST698', Decimal('0.9808')),
#  ('ST699', Decimal('0.9616')),
#  ('ST7', Decimal('0.6192')),
#  ('ST70', Decimal('0.7041')),
#  ('ST700', Decimal('0.9890')),
#  ('ST701', Decimal('0.9836')),
#  ('ST702', Decimal('0.9781')),
#  ('ST703', Decimal('0.9836')),
#  ('ST704', Decimal('0.9699')),
#  ('ST705', Decimal('0.9726')),
#  ('ST706', Decimal('0.9890')),
#  ('ST707', Decimal('0.9753')),
#  ('ST708', Decimal('0.9753')),
#  ('ST709', Decimal('0.9808')),
#  ('ST71', Decimal('0.4438')),
#  ('ST710', Decimal('0.9726')),
#  ('ST711', Decimal('0.9808')),
#  ('ST712', Decimal('0.9863')),
#  ('ST713', Decimal('0.9836')),
#  ('ST714', Decimal('0.9863')),
#  ('ST715', Decimal('0.9836')),
#  ('ST716', Decimal('0.9836')),
#  ('ST717', Decimal('0.9781')),
#  ('ST718', Decimal('0.9863')),
#  ('ST719', Decimal('0.9781')),
#  ('ST72', Decimal('0.4466')),
#  ('ST720', Decimal('0.9890')),
#  ('ST721', Decimal('0.9671')),
#  ('ST722', Decimal('0.9671')),
#  ('ST723', Decimal('0.9836')),
#  ('ST724', Decimal('0.9836')),
#  ('ST725', Decimal('0.9808')),
#  ('ST726', Decimal('0.9726')),
#  ('ST727', Decimal('0.9863')),
#  ('ST728', Decimal('0.9808')),
#  ('ST729', Decimal('0.9918')),
#  ('ST73', Decimal('0.4219')),
#  ('ST730', Decimal('0.9616')),
#  ('ST731', Decimal('0.9836')),
#  ('ST732', Decimal('0.9726')),
#  ('ST733', Decimal('0.9863')),
#  ('ST734', Decimal('0.9644')),
#  ('ST735', Decimal('0.9836')),
#  ('ST736', Decimal('0.9918')),
#  ('ST737', Decimal('0.9753')),
#  ('ST738', Decimal('0.9836')),
#  ('ST739', Decimal('0.9890')),
#  ('ST74', Decimal('0.5918')),
#  ('ST740', Decimal('0.9863')),
#  ('ST741', Decimal('0.9781')),
#  ('ST742', Decimal('0.9863')),
#  ('ST743', Decimal('0.9918')),
#  ('ST744', Decimal('0.9808')),
#  ('ST745', Decimal('0.9808')),
#  ('ST746', Decimal('0.9836')),
#  ('ST747', Decimal('0.9808')),
#  ('ST748', Decimal('0.9836')),
#  ('ST749', Decimal('0.9863')),
#  ('ST75', Decimal('0.5726')),
#  ('ST750', Decimal('0.9808')),
#  ('ST751', Decimal('0.9890')),
#  ('ST752', Decimal('0.9753')),
#  ('ST753', Decimal('0.9753')),
#  ('ST754', Decimal('0.9863')),
#  ('ST755', Decimal('0.9890')),
#  ('ST756', Decimal('0.9808')),
#  ('ST757', Decimal('0.9836')),
#  ('ST758', Decimal('0.9808')),
#  ('ST759', Decimal('0.9644')),
#  ('ST76', Decimal('0.4247')),
#  ('ST760', Decimal('0.9836')),
#  ('ST761', Decimal('0.9836')),
#  ('ST762', Decimal('0.9808')),
#  ('ST763', Decimal('0.9699')),
#  ('ST764', Decimal('0.9808')),
#  ('ST765', Decimal('0.9753')),
#  ('ST766', Decimal('0.9726')),
#  ('ST767', Decimal('0.9808')),
#  ('ST768', Decimal('0.9890')),
#  ('ST769', Decimal('0.9808')),
#  ('ST77', Decimal('0.0795')),
#  ('ST770', Decimal('0.9699')),
#  ('ST771', Decimal('0.9753')),
#  ('ST772', Decimal('0.9671')),
#  ('ST773', Decimal('0.9781')),
#  ('ST774', Decimal('0.9808')),
#  ('ST775', Decimal('0.9726')),
#  ('ST776', Decimal('0.9890')),
#  ('ST777', Decimal('0.9808')),
#  ('ST778', Decimal('0.9918')),
#  ('ST779', Decimal('0.9808')),
#  ('ST78', Decimal('0.3178')),
#  ('ST780', Decimal('0.9781')),
#  ('ST781', Decimal('0.9890')),
#  ('ST782', Decimal('0.9808')),
#  ('ST783', Decimal('0.9863')),
#  ('ST784', Decimal('0.9726')),
#  ('ST785', Decimal('0.9726')),
#  ('ST786', Decimal('0.9781')),
#  ('ST787', Decimal('0.9699')),
#  ('ST788', Decimal('0.9808')),
#  ('ST789', Decimal('0.9836')),
#  ('ST79', Decimal('0.3123')),
#  ('ST790', Decimal('0.9836')),
#  ('ST791', Decimal('0.9863')),
#  ('ST792', Decimal('0.9808')),
#  ('ST793', Decimal('0.9808')),
#  ('ST794', Decimal('0.9808')),
#  ('ST795', Decimal('0.9726')),
#  ('ST796', Decimal('0.9808')),
#  ('ST797', Decimal('0.9863')),
#  ('ST798', Decimal('0.9863')),
#  ('ST799', Decimal('0.9863')),
#  ('ST8', Decimal('0.3973')),
#  ('ST80', Decimal('0.6110')),
#  ('ST800', Decimal('0.9808')),
#  ('ST801', Decimal('0.9781')),
#  ('ST802', Decimal('0.9836')),
#  ('ST803', Decimal('0.9808')),
#  ('ST804', Decimal('0.9863')),
#  ('ST805', Decimal('0.9836')),
#  ('ST806', Decimal('0.9918')),
#  ('ST807', Decimal('0.9836')),
#  ('ST808', Decimal('0.9808')),
#  ('ST809', Decimal('0.9945')),
#  ('ST81', Decimal('0.2329')),
#  ('ST810', Decimal('0.9890')),
#  ('ST811', Decimal('0.9699')),
#  ('ST812', Decimal('0.9808')),
#  ('ST813', Decimal('0.9781')),
#  ('ST814', Decimal('0.9918')),
#  ('ST815', Decimal('0.9781')),
#  ('ST816', Decimal('0.9808')),
#  ('ST817', Decimal('0.9890')),
#  ('ST818', Decimal('0.9836')),
#  ('ST819', Decimal('0.9699')),
#  ('ST82', Decimal('0.5068')),
#  ('ST820', Decimal('0.9836')),
#  ('ST821', Decimal('0.9836')),
#  ('ST822', Decimal('0.9753')),
#  ('ST823', Decimal('0.9808')),
#  ('ST824', Decimal('0.9534')),
#  ('ST825', Decimal('0.9863')),
#  ('ST826', Decimal('0.9836')),
#  ('ST827', Decimal('0.9808')),
#  ('ST828', Decimal('0.9753')),
#  ('ST829', Decimal('0.9836')),
#  ('ST83', Decimal('0.6164')),
#  ('ST830', Decimal('0.9699')),
#  ('ST831', Decimal('0.9863')),
#  ('ST832', Decimal('0.9808')),
#  ('ST833', Decimal('0.9808')),
#  ('ST834', Decimal('0.9726')),
#  ('ST835', Decimal('0.9808')),
#  ('ST836', Decimal('0.9808')),
#  ('ST837', Decimal('0.9781')),
#  ('ST838', Decimal('0.9808')),
#  ('ST839', Decimal('0.9836')),
#  ('ST84', Decimal('0.1014')),
#  ('ST840', Decimal('0.9644')),
#  ('ST841', Decimal('0.9836')),
#  ('ST842', Decimal('0.9836')),
#  ('ST843', Decimal('0.9781')),
#  ('ST844', Decimal('0.9863')),
#  ('ST845', Decimal('0.9836')),
#  ('ST846', Decimal('0.9890')),
#  ('ST847', Decimal('0.9808')),
#  ('ST848', Decimal('0.9808')),
#  ('ST849', Decimal('0.9890')),
#  ('ST85', Decimal('0.3151')),
#  ('ST850', Decimal('0.9863')),
#  ('ST851', Decimal('0.9836')),
#  ('ST852', Decimal('0.9726')),
#  ('ST853', Decimal('0.9836')),
#  ('ST854', Decimal('0.9781')),
#  ('ST855', Decimal('0.9808')),
#  ('ST856', Decimal('0.9781')),
#  ('ST857', Decimal('0.9836')),
#  ('ST858', Decimal('0.9836')),
#  ('ST859', Decimal('0.9918')),
#  ('ST86', Decimal('0.6521')),
#  ('ST860', Decimal('0.9890')),
#  ('ST861', Decimal('0.9918')),
#  ('ST862', Decimal('0.9863')),
#  ('ST863', Decimal('0.9808')),
#  ('ST864', Decimal('0.9808')),
#  ('ST865', Decimal('0.9781')),
#  ('ST866', Decimal('0.9890')),
#  ('ST867', Decimal('0.9699')),
#  ('ST868', Decimal('0.9890')),
#  ('ST869', Decimal('0.9863')),
#  ('ST87', Decimal('0.5123')),
#  ('ST870', Decimal('0.9699')),
#  ('ST871', Decimal('0.9918')),
#  ('ST872', Decimal('0.9836')),
#  ('ST873', Decimal('0.9781')),
#  ('ST874', Decimal('0.9808')),
#  ('ST875', Decimal('0.9836')),
#  ('ST876', Decimal('0.9671')),
#  ('ST877', Decimal('0.9699')),
#  ('ST878', Decimal('0.9699')),
#  ('ST879', Decimal('0.9753')),
#  ('ST88', Decimal('0.6274')),
#  ('ST880', Decimal('0.9781')),
#  ('ST881', Decimal('0.9863')),
#  ('ST882', Decimal('0.9863')),
#  ('ST883', Decimal('0.9808')),
#  ('ST884', Decimal('0.9808')),
#  ('ST885', Decimal('0.9781')),
#  ('ST886', Decimal('0.9781')),
#  ('ST887', Decimal('0.9863')),
#  ('ST888', Decimal('0.9863')),
#  ('ST889', Decimal('0.9808')),
#  ('ST89', Decimal('0.3973')),
#  ('ST890', Decimal('0.9890')),
#  ('ST891', Decimal('0.9890')),
#  ('ST892', Decimal('0.9890')),
#  ('ST893', Decimal('0.9808')),
#  ('ST894', Decimal('0.9781')),
#  ('ST895', Decimal('0.9726')),
#  ('ST896', Decimal('0.9836')),
#  ('ST897', Decimal('0.9863')),
#  ('ST898', Decimal('0.9863')),
#  ('ST899', Decimal('0.9753')),
#  ('ST9', Decimal('0.3753')),
#  ('ST90', Decimal('0.3342')),
#  ('ST900', Decimal('0.9890')),
#  ('ST901', Decimal('0.9836')),
#  ('ST902', Decimal('0.9699')),
#  ('ST903', Decimal('0.9616')),
#  ('ST904', Decimal('0.9781')),
#  ('ST905', Decimal('0.9890')),
#  ('ST906', Decimal('0.9699')),
#  ('ST907', Decimal('0.9753')),
#  ('ST908', Decimal('0.9890')),
#  ('ST909', Decimal('0.9808')),
#  ('ST91', Decimal('0.3616')),
#  ('ST910', Decimal('0.9644')),
#  ('ST911', Decimal('0.9671')),
#  ('ST912', Decimal('0.9836')),
#  ('ST913', Decimal('0.9753')),
#  ('ST914', Decimal('0.9781')),
#  ('ST915', Decimal('0.9808')),
#  ('ST916', Decimal('0.9808')),
#  ('ST917', Decimal('0.9836')),
#  ('ST918', Decimal('0.9808')),
#  ('ST919', Decimal('0.9616')),
#  ('ST92', Decimal('0.2658')),
#  ('ST920', Decimal('0.9753')),
#  ('ST921', Decimal('0.9918')),
#  ('ST922', Decimal('0.9781')),
#  ('ST923', Decimal('0.9699')),
#  ('ST924', Decimal('0.9808')),
#  ('ST925', Decimal('0.9890')),
#  ('ST926', Decimal('0.9808')),
#  ('ST927', Decimal('0.9808')),
#  ('ST928', Decimal('0.9890')),
#  ('ST929', Decimal('0.9753')),
#  ('ST93', Decimal('0.3863')),
#  ('ST930', Decimal('0.9836')),
#  ('ST931', Decimal('0.9808')),
#  ('ST932', Decimal('0.9836')),
#  ('ST933', Decimal('0.9753')),
#  ('ST934', Decimal('0.9890')),
#  ('ST935', Decimal('0.9781')),
#  ('ST936', Decimal('0.9863')),
#  ('ST937', Decimal('0.9945')),
#  ('ST938', Decimal('0.9863')),
#  ('ST939', Decimal('0.9836')),
#  ('ST94', Decimal('0.3151')),
#  ('ST940', Decimal('0.9753')),
#  ('ST941', Decimal('0.9918')),
#  ('ST942', Decimal('0.9753')),
#  ('ST943', Decimal('0.9808')),
#  ('ST944', Decimal('0.9808')),
#  ('ST945', Decimal('0.9781')),
#  ('ST946', Decimal('0.9699')),
#  ('ST947', Decimal('0.9918')),
#  ('ST948', Decimal('0.9863')),
#  ('ST949', Decimal('0.9890')),
#  ('ST95', Decimal('0.5562')),
#  ('ST950', Decimal('0.9808')),
#  ('ST951', Decimal('0.9753')),
#  ('ST952', Decimal('0.9726')),
#  ('ST953', Decimal('0.9836')),
#  ('ST954', Decimal('0.9726')),
#  ('ST955', Decimal('0.9808')),
#  ('ST956', Decimal('0.9863')),
#  ('ST957', Decimal('0.9863')),
#  ('ST958', Decimal('0.9863')),
#  ('ST959', Decimal('0.9781')),
#  ('ST96', Decimal('0.4493')),
#  ('ST960', Decimal('0.9890')),
#  ('ST961', Decimal('0.9808')),
#  ('ST962', Decimal('0.9781')),
#  ('ST963', Decimal('0.9863')),
#  ('ST964', Decimal('0.9836')),
#  ('ST965', Decimal('0.9726')),
#  ('ST966', Decimal('0.9863')),
#  ('ST967', Decimal('0.9616')),
#  ('ST968', Decimal('0.9781')),
#  ('ST969', Decimal('0.9836')),
#  ('ST97', Decimal('0.3178')),
#  ('ST970', Decimal('0.9808')),
#  ('ST971', Decimal('0.9863')),
#  ('ST972', Decimal('0.9863')),
#  ('ST973', Decimal('0.9808')),
#  ('ST974', Decimal('0.9753')),
#  ('ST975', Decimal('0.9781')),
#  ('ST976', Decimal('0.9836')),
#  ('ST977', Decimal('0.9781')),
#  ('ST978', Decimal('0.9753')),
#  ('ST979', Decimal('0.9836')),
#  ('ST98', Decimal('0.5123')),
#  ('ST980', Decimal('0.9781')),
#  ('ST981', Decimal('0.9726')),
#  ('ST982', Decimal('0.9671')),
#  ('ST983', Decimal('0.9808')),
#  ('ST984', Decimal('0.9781')),
#  ('ST985', Decimal('0.9781')),
#  ('ST986', Decimal('0.9863')),
#  ('ST987', Decimal('0.9836')),
#  ('ST988', Decimal('0.9699')),
#  ('ST989', Decimal('0.9836')),
#  ('ST99', Decimal('0.3699')),
#  ('ST990', Decimal('0.9781')),
#  ('ST991', Decimal('0.9671')),
#  ('ST992', Decimal('0.9890')),
#  ('ST993', Decimal('0.9808')),
#  ('ST994', Decimal('0.9863')),
#  ('ST995', Decimal('0.9863')),
#  ('ST996', Decimal('0.9781')),
#  ('ST997', Decimal('0.9945')),
#  ('ST998', Decimal('0.9836')),
#  ('ST999', Decimal('0.9781'))]

# %%
# %%sql
# SELECT * FROM watershed_property_info LIMIT 1;
# Out:
# 1 rows affected.
# [('W1', 'L9531', 'R6', 1060)]

# %%
#to get all the data from watershed as needed for next quiz
# %%sql
SELECT w.ws_property_id, st.location, l.city, l.state, l.zipcode,
p.apt_house, p.num_bedrooms, p.kitchen, p.shared, w.current_monthly_rent,
srp.percentile_10th_price, srp.percentile_90th_price, srp.sample_nightly_rent_price,
combined.occupy_rate, combined.st_property, st.property_type

FROM (SELECT st_property, COUNT(DISTINCT rental_date)/365 AS occupy_rate 
FROM st_rental_dates WHERE rental_date > '2014-12-31' AND rental_date <= '2015-12-31'
GROUP BY st_property)  AS combined
JOIN st_property_info st ON combined.st_property = st.st_property_id
JOIN watershed_property_info w ON st.location = w.location 
AND st.property_type = w.property_type
JOIN location l ON st.location = l.location_id
JOIN property_type p ON st.property_type = p.property_type_id
JOIN st_rental_prices srp ON srp.location = st.location 
AND srp.property_type = st.property_type
# Out:
# 244 rows affected.
# [('W1', 'L9531', 'Chapel Hill', 'NC', 27514, 'apartment', '2', 'Y', 'N', 1060, 114, 153, 148, Decimal('0.1616'), 'ST1', 'R6'),
#  ('W10', 'L9533', 'Chapel Hill', 'NC', 27517, 'apartment', '2', 'Y', 'N', 1200, 111, 149, 133, Decimal('0.3479'), 'ST10', 'R6'),
#  ('W100', 'L1944', 'San Francisco', 'CA', 94129, 'apartment', '1', 'Y', 'N', 3300, 108, 610, 372, Decimal('0.3973'), 'ST100', 'R2'),
#  ('W101', 'L15257', 'Austin', 'TX', 78702, 'apartment', '1', 'Y', 'N', 1400, 178, 533, 302, Decimal('0.3644'), 'ST101', 'R2'),
#  ('W102', 'L15257', 'Austin', 'TX', 78702, 'apartment', '2', 'Y', 'N', 2000, 221, 617, 429, Decimal('0.4110'), 'ST102', 'R6'),
#  ('W103', 'L15257', 'Austin', 'TX', 78702, 'house', '1', 'Y', 'N', 1600, 202, 646, 380, Decimal('0.4110'), 'ST103', 'R10'),
#  ('W104', 'L15257', 'Austin', 'TX', 78702, 'house', '2', 'Y', 'N', 2800, 197, 639, 374, Decimal('0.5260'), 'ST104', 'R14'),
#  ('W105', 'L15260', 'Austin', 'TX', 78705, 'apartment', '1', 'Y', 'N', 1100, 114, 477, 386, Decimal('0.4329'), 'ST105', 'R2'),
#  ('W106', 'L15260', 'Austin', 'TX', 78705, 'apartment', '2', 'Y', 'N', 1900, 80, 583, 212, Decimal('0.6959'), 'ST106', 'R6'),
#  ('W107', 'L15260', 'Austin', 'TX', 78705, 'house', '1', 'Y', 'N', 1800, 239, 1431, 969, Decimal('0.1096'), 'ST107', 'R10'),
#  ('W108', 'L15260', 'Austin', 'TX', 78705, 'house', '2', 'Y', 'N', 3200, 236, 1533, 885, Decimal('0.2247'), 'ST108', 'R14'),
#  ('W109', 'L15264', 'Austin', 'TX', 78723, 'apartment', '1', 'Y', 'N', 1000, 138, 550, 287, Decimal('0.2192'), 'ST109', 'R2'),
#  ('W11', 'L9533', 'Chapel Hill', 'NC', 27517, 'house', '1', 'Y', 'N', 1000, 116, 296, 206, Decimal('0.3918'), 'ST11', 'R10'),
#  ('W110', 'L15264', 'Austin', 'TX', 78723, 'apartment', '2', 'Y', 'N', 1300, 175, 917, 462, Decimal('0.5370'), 'ST110', 'R6'),
#  ('W111', 'L15264', 'Austin', 'TX', 78723, 'house', '1', 'Y', 'N', 1200, 130, 821, 389, Decimal('0.5123'), 'ST111', 'R10'),
#  ('W112', 'L15264', 'Austin', 'TX', 78723, 'house', '2', 'Y', 'N', 1600, 241, 866, 678, Decimal('0.3616'), 'ST112', 'R14'),
#  ('W113', 'L15278', 'Austin', 'TX', 78744, 'apartment', '1', 'Y', 'N', 800, 134, 288, 163, Decimal('0.8438'), 'ST113', 'R2'),
#  ('W114', 'L15278', 'Austin', 'TX', 78744, 'apartment', '2', 'Y', 'N', 1200, 234, 794, 374, Decimal('0.9151'), 'ST114', 'R6'),
#  ('W115', 'L15278', 'Austin', 'TX', 78744, 'house', '1', 'Y', 'N', 900, 252, 547, 444, Decimal('0.4301'), 'ST115', 'R10'),
#  ('W116', 'L15278', 'Austin', 'TX', 78744, 'house', '2', 'Y', 'N', 1100, 246, 616, 426, Decimal('0.4822'), 'ST116', 'R14'),
#  ('W117', 'L15280', 'Austin', 'TX', 78746, 'apartment', '1', 'Y', 'N', 1000, 171, 457, 332, Decimal('0.4904'), 'ST117', 'R2'),
#  ('W118', 'L15280', 'Austin', 'TX', 78746, 'apartment', '2', 'Y', 'N', 1400, 262, 567, 430, Decimal('0.5233'), 'ST118', 'R6'),
#  ('W119', 'L15280', 'Austin', 'TX', 78746, 'house', '1', 'Y', 'N', 1500, 229, 859, 662, Decimal('0.4493'), 'ST119', 'R10'),
#  ('W12', 'L9533', 'Chapel Hill', 'NC', 27517, 'house', '2', 'Y', 'N', 1300, 136, 336, 186, Decimal('0.6603'), 'ST12', 'R14'),
#  ('W120', 'L15280', 'Austin', 'TX', 78746, 'house', '2', 'Y', 'N', 1600, 449, 899, 696, Decimal('0.4877'), 'ST120', 'R14'),
#  ('W121', 'L463', 'Bentonville', 'AR', 72712, 'apartment', '1', 'Y', 'N', 600, 132, 226, 182, Decimal('0.4384'), 'ST121', 'R2'),
#  ('W122', 'L463', 'Bentonville', 'AR', 72712, 'apartment', '2', 'Y', 'N', 800, 157, 340, 241, Decimal('0.5315'), 'ST122', 'R6'),
#  ('W123', 'L463', 'Bentonville', 'AR', 72712, 'house', '1', 'Y', 'N', 700, 215, 377, 363, Decimal('0.1397'), 'ST123', 'R10'),
#  ('W124', 'L463', 'Bentonville', 'AR', 72712, 'house', '2', 'Y', 'N', 1000, 202, 374, 301, Decimal('0.4685'), 'ST124', 'R14'),
#  ('W125', 'L464', 'Bentonville', 'AR', 72719, 'apartment', '1', 'Y', 'N', 700, 94, 356, 212, Decimal('0.5014'), 'ST125', 'R2'),
#  ('W126', 'L464', 'Bentonville', 'AR', 72719, 'apartment', '2', 'Y', 'N', 900, 69, 485, 340, Decimal('0.3068'), 'ST126', 'R6'),
#  ('W127', 'L464', 'Bentonville', 'AR', 72719, 'house', '1', 'Y', 'N', 1000, 84, 376, 266, Decimal('0.5205'), 'ST127', 'R10'),
#  ('W128', 'L464', 'Bentonville', 'AR', 72719, 'house', '2', 'Y', 'N', 1200, 109, 490, 442, Decimal('0.1288'), 'ST128', 'R14'),
#  ('W129', 'L2314', 'Denver', 'CO', 80204, 'apartment', '1', 'Y', 'N', 1200, 145, 434, 354, Decimal('0.2411'), 'ST129', 'R2'),
#  ('W13', 'L9534', 'Chapel Hill', 'NC', 27707, 'apartment', '2', 'Y', 'N', 920, 111, 147, 123, Decimal('0.4521'), 'ST13', 'R6'),
#  ('W130', 'L2314', 'Denver', 'CO', 80204, 'apartment', '2', 'Y', 'N', 1300, 228, 457, 377, Decimal('0.4795'), 'ST130', 'R6'),
#  ('W131', 'L2314', 'Denver', 'CO', 80204, 'house', '1', 'Y', 'N', 1100, 90, 375, 318, Decimal('0.2712'), 'ST131', 'R10'),
#  ('W132', 'L2314', 'Denver', 'CO', 80204, 'house', '2', 'Y', 'N', 1200, 128, 238, 198, Decimal('0.4301'), 'ST132', 'R14'),
#  ('W133', 'L2318', 'Denver', 'CO', 80209, 'apartment', '1', 'Y', 'N', 1300, 126, 188, 149, Decimal('0.5671'), 'ST133', 'R2'),
#  ('W134', 'L2318', 'Denver', 'CO', 80209, 'apartment', '2', 'Y', 'N', 1700, 152, 247, 210, Decimal('0.3205'), 'ST134', 'R6'),
#  ('W135', 'L2318', 'Denver', 'CO', 80209, 'house', '1', 'Y', 'N', 1200, 141, 263, 187, Decimal('0.4493'), 'ST135', 'R10'),
#  ('W136', 'L2318', 'Denver', 'CO', 80209, 'house', '2', 'Y', 'N', 1900, 157, 314, 225, Decimal('0.5096'), 'ST136', 'R14'),
#  ('W137', 'L2323', 'Denver', 'CO', 80218, 'apartment', '1', 'Y', 'N', 1000, 93, 159, 123, Decimal('0.7205'), 'ST137', 'R2'),
#  ('W138', 'L2323', 'Denver', 'CO', 80218, 'apartment', '2', 'Y', 'N', 1500, 145, 462, 263, Decimal('0.4959'), 'ST138', 'R6'),
#  ('W139', 'L2323', 'Denver', 'CO', 80218, 'house', '1', 'Y', 'N', 1300, 181, 316, 238, Decimal('0.4493'), 'ST139', 'R10'),
#  ('W14', 'L9534', 'Chapel Hill', 'NC', 27707, 'house', '1', 'Y', 'N', 850, 96, 245, 146, Decimal('0.5315'), 'ST14', 'R10'),
#  ('W140', 'L2323', 'Denver', 'CO', 80218, 'house', '2', 'Y', 'N', 1800, 145, 412, 349, Decimal('0.1507'), 'ST140', 'R14'),
#  ('W141', 'L2325', 'Denver', 'CO', 80220, 'apartment', '1', 'Y', 'N', 1100, 99, 215, 147, Decimal('0.6000'), 'ST141', 'R2'),
#  ('W142', 'L2325', 'Denver', 'CO', 80220, 'apartment', '2', 'Y', 'N', 1400, 120, 188, 151, Decimal('0.5260'), 'ST142', 'R6'),
#  ('W143', 'L2325', 'Denver', 'CO', 80220, 'house', '1', 'Y', 'N', 1300, 263, 489, 429, Decimal('0.2110'), 'ST143', 'R10'),
#  ('W144', 'L2325', 'Denver', 'CO', 80220, 'house', '2', 'Y', 'N', 1900, 335, 502, 441, Decimal('0.3315'), 'ST144', 'R14'),
#  ('W145', 'L2338', 'Denver', 'CO', 80249, 'apartment', '1', 'Y', 'N', 900, 98, 195, 144, Decimal('0.3288'), 'ST145', 'R2'),
#  ('W146', 'L2338', 'Denver', 'CO', 80249, 'apartment', '2', 'Y', 'N', 1400, 77, 260, 136, Decimal('0.6192'), 'ST146', 'R6'),
#  ('W147', 'L2338', 'Denver', 'CO', 80249, 'house', '1', 'Y', 'N', 1400, 173, 322, 305, Decimal('0.2712'), 'ST147', 'R10'),
#  ('W148', 'L2338', 'Denver', 'CO', 80249, 'house', '2', 'Y', 'N', 1700, 176, 469, 425, Decimal('0.3288'), 'ST148', 'R14'),
#  ('W149', 'L3244', 'Miami', 'FL', 33122, 'apartment', '1', 'Y', 'N', 800, 86, 224, 176, Decimal('0.4137'), 'ST149', 'R2'),
#  ('W15', 'L9534', 'Chapel Hill', 'NC', 27707, 'house', '2', 'Y', 'N', 900, 111, 276, 169, Decimal('0.4795'), 'ST15', 'R14'),
#  ('W150', 'L3244', 'Miami', 'FL', 33122, 'apartment', '2', 'Y', 'N', 1300, 127, 276, 207, Decimal('0.6301'), 'ST150', 'R6'),
#  ('W151', 'L3244', 'Miami', 'FL', 33122, 'house', '1', 'Y', 'N', 1400, 222, 381, 244, Decimal('0.9041'), 'ST151', 'R10'),
#  ('W152', 'L3244', 'Miami', 'FL', 33122, 'house', '2', 'Y', 'N', 1900, 386, 773, 536, Decimal('0.5425'), 'ST152', 'R14'),
#  ('W153', 'L3256', 'Miami', 'FL', 33137, 'apartment', '1', 'Y', 'N', 1700, 136, 476, 476, Decimal('0.0795'), 'ST153', 'R2'),
#  ('W154', 'L3256', 'Miami', 'FL', 33137, 'apartment', '2', 'Y', 'N', 2400, 173, 690, 360, Decimal('0.5507'), 'ST154', 'R6'),
#  ('W155', 'L3256', 'Miami', 'FL', 33137, 'house', '1', 'Y', 'N', 2100, 448, 2128, 1477, Decimal('0.6932'), 'ST155', 'R10'),
#  ('W156', 'L3256', 'Miami', 'FL', 33137, 'house', '2', 'Y', 'N', 3200, 450, 2699, 1265, Decimal('0.7151'), 'ST156', 'R14'),
#  ('W157', 'L3261', 'Miami', 'FL', 33146, 'apartment', '1', 'Y', 'N', 1300, 291, 387, 328, Decimal('0.5205'), 'ST157', 'R2'),
#  ('W158', 'L3261', 'Miami', 'FL', 33146, 'apartment', '2', 'Y', 'N', 1700, 203, 318, 246, Decimal('0.1589'), 'ST158', 'R6'),
#  ('W159', 'L3261', 'Miami', 'FL', 33146, 'house', '1', 'Y', 'N', 1400, 287, 395, 325, Decimal('0.5452'), 'ST159', 'R10'),
#  ('W16', 'L9534', 'Chapel Hill', 'NC', 27707, 'apartment', '1', 'Y', 'N', 750, 51, 179, 94, Decimal('0.4795'), 'ST16', 'R2'),
#  ('W160', 'L3261', 'Miami', 'FL', 33146, 'house', '2', 'Y', 'N', 1900, 376, 502, 428, Decimal('0.5863'), 'ST160', 'R14'),
#  ('W161', 'L3262', 'Miami', 'FL', 33149, 'apartment', '1', 'Y', 'N', 1600, 126, 352, 188, Decimal('0.6795'), 'ST161', 'R2'),
#  ('W162', 'L3262', 'Miami', 'FL', 33149, 'apartment', '2', 'Y', 'N', 2200, 119, 505, 274, Decimal('0.5781'), 'ST162', 'R6'),
#  ('W163', 'L3262', 'Miami', 'FL', 33149, 'house', '1', 'Y', 'N', 1500, 486, 1215, 860, Decimal('0.4110'), 'ST163', 'R10'),
#  ('W164', 'L3262', 'Miami', 'FL', 33149, 'house', '2', 'Y', 'N', 2400, 516, 1650, 729, Decimal('0.6822'), 'ST164', 'R14'),
#  ('W165', 'L3264', 'Miami', 'FL', 33178, 'apartment', '1', 'Y', 'N', 1600, 160, 321, 174, Decimal('0.8247'), 'ST165', 'R2'),
#  ('W166', 'L3264', 'Miami', 'FL', 33178, 'apartment', '2', 'Y', 'N', 1900, 168, 364, 308, Decimal('0.2164'), 'ST166', 'R6'),
#  ('W167', 'L3264', 'Miami', 'FL', 33178, 'house', '1', 'Y', 'N', 1400, 226, 368, 308, Decimal('0.6000'), 'ST167', 'R10'),
#  ('W168', 'L3264', 'Miami', 'FL', 33178, 'house', '2', 'Y', 'N', 2000, 285, 428, 342, Decimal('0.3918'), 'ST168', 'R14'),
#  ('W169', 'L10126', 'Omaha', 'NE', 68046, 'apartment', '1', 'Y', 'N', 1000, 91, 342, 229, Decimal('0.5890'), 'ST169', 'R2'),
#  ('W17', 'L4761', 'Chicago', 'IL', 60607, 'apartment', '2', 'Y', 'N', 2500, 173, 581, 392, Decimal('0.2932'), 'ST17', 'R6'),
#  ('W170', 'L10126', 'Omaha', 'NE', 68046, 'apartment', '2', 'Y', 'N', 1400, 168, 392, 322, Decimal('0.2712'), 'ST170', 'R6'),
#  ('W171', 'L10126', 'Omaha', 'NE', 68046, 'house', '1', 'Y', 'N', 1300, 155, 494, 257, Decimal('0.5507'), 'ST171', 'R10'),
#  ('W172', 'L10126', 'Omaha', 'NE', 68046, 'house', '2', 'Y', 'N', 1800, 151, 391, 286, Decimal('0.4521'), 'ST172', 'R14'),
#  ('W173', 'L10130', 'Omaha', 'NE', 68106, 'apartment', '1', 'Y', 'N', 700, 99, 265, 180, Decimal('0.5178'), 'ST173', 'R2'),
#  ('W174', 'L10130', 'Omaha', 'NE', 68106, 'apartment', '2', 'Y', 'N', 900, 154, 286, 230, Decimal('0.5205'), 'ST174', 'R6'),
#  ('W175', 'L10130', 'Omaha', 'NE', 68106, 'house', '1', 'Y', 'N', 1000, 190, 462, 221, Decimal('0.6301'), 'ST175', 'R10'),
#  ('W176', 'L10130', 'Omaha', 'NE', 68106, 'house', '2', 'Y', 'N', 1200, 205, 411, 316, Decimal('0.3699'), 'ST176', 'R14'),
#  ('W177', 'L10133', 'Omaha', 'NE', 68110, 'apartment', '1', 'Y', 'N', 700, 192, 313, 245, Decimal('0.5699'), 'ST177', 'R2'),
#  ('W178', 'L10133', 'Omaha', 'NE', 68110, 'apartment', '2', 'Y', 'N', 1000, 192, 357, 266, Decimal('0.4192'), 'ST178', 'R6'),
#  ('W179', 'L10133', 'Omaha', 'NE', 68110, 'house', '1', 'Y', 'N', 800, 186, 465, 325, Decimal('0.4548'), 'ST179', 'R10'),
#  ('W18', 'L4761', 'Chicago', 'IL', 60607, 'house', '1', 'Y', 'N', 2500, 189, 588, 393, Decimal('0.6219'), 'ST18', 'R10'),
#  ('W180', 'L10133', 'Omaha', 'NE', 68110, 'house', '2', 'Y', 'N', 900, 209, 358, 256, Decimal('0.7096'), 'ST180', 'R14'),
#  ('W181', 'L10136', 'Omaha', 'NE', 68114, 'apartment', '1', 'Y', 'N', 700, 42, 252, 184, Decimal('0.3096'), 'ST181', 'R2'),
#  ('W182', 'L10136', 'Omaha', 'NE', 68114, 'apartment', '2', 'Y', 'N', 1000, 94, 531, 427, Decimal('0.2411'), 'ST182', 'R6'),
#  ('W183', 'L10136', 'Omaha', 'NE', 68114, 'house', '1', 'Y', 'N', 900, 86, 488, 418, Decimal('0.0466'), 'ST183', 'R10'),
#  ('W184', 'L10136', 'Omaha', 'NE', 68114, 'house', '2', 'Y', 'N', 1200, 83, 556, 219, Decimal('0.6356'), 'ST184', 'R14'),
#  ('W185', 'L1882', 'San Diego', 'CA', 91910, 'apartment', '1', 'Y', 'N', 1100, 84, 301, 220, Decimal('0.4301'), 'ST185', 'R2'),
#  ('W186', 'L1882', 'San Diego', 'CA', 91910, 'apartment', '2', 'Y', 'N', 1400, 134, 568, 481, Decimal('0.3808'), 'ST186', 'R6'),
#  ('W187', 'L1882', 'San Diego', 'CA', 91910, 'house', '1', 'Y', 'N', 1300, 109, 615, 280, Decimal('0.4575'), 'ST187', 'R10'),
#  ('W19', 'L4761', 'Chicago', 'IL', 60607, 'house', '2', 'Y', 'N', 2800, 191, 826, 556, Decimal('0.2986'), 'ST19', 'R14'),
#  ('W191', 'L1883', 'San Diego', 'CA', 91950, 'house', '1', 'Y', 'N', 1300, 157, 471, 318, Decimal('0.3918'), 'ST191', 'R10'),
#  ('W192', 'L1883', 'San Diego', 'CA', 91950, 'house', '2', 'Y', 'N', 1600, 253, 886, 680, Decimal('0.3863'), 'ST192', 'R14'),
#  ('W193', 'L1887', 'San Diego', 'CA', 92102, 'apartment', '1', 'Y', 'N', 1400, 76, 342, 202, Decimal('0.4877'), 'ST193', 'R2'),
#  ('W194', 'L1887', 'San Diego', 'CA', 92102, 'apartment', '2', 'Y', 'N', 2000, 107, 781, 579, Decimal('0.4110'), 'ST194', 'R6'),
#  ('W195', 'L1887', 'San Diego', 'CA', 92102, 'house', '1', 'Y', 'N', 1700, 162, 614, 524, Decimal('0.5041'), 'ST195', 'R10'),
#  ('W196', 'L1887', 'San Diego', 'CA', 92102, 'house', '2', 'Y', 'N', 2500, 158, 906, 560, Decimal('0.2767'), 'ST196', 'R14'),
#  ('W197', 'L1902', 'San Diego', 'CA', 92118, 'apartment', '1', 'Y', 'N', 1800, 199, 432, 362, Decimal('0.3288'), 'ST197', 'R2'),
#  ('W198', 'L1902', 'San Diego', 'CA', 92118, 'apartment', '2', 'Y', 'N', 2600, 366, 594, 417, Decimal('0.5315'), 'ST198', 'R6'),
#  ('W199', 'L1902', 'San Diego', 'CA', 92118, 'house', '1', 'Y', 'N', 2500, 333, 665, 474, Decimal('0.4274'), 'ST199', 'R10'),
#  ('W2', 'L9531', 'Chapel Hill', 'NC', 27514, 'house', '1', 'Y', 'N', 1500, 81, 205, 146, Decimal('0.2411'), 'ST2', 'R10'),
#  ('W188', 'L1882', 'San Diego', 'CA', 91910, 'house', '2', 'Y', 'N', 1900, 227, 861, 568, Decimal('0.1890'), 'ST488', 'R14'),
#  ('W189', 'L1883', 'San Diego', 'CA', 91950, 'apartment', '1', 'Y', 'N', 900, 176, 440, 318, Decimal('0.2904'), 'ST489', 'R2'),
#  ('W190', 'L1883', 'San Diego', 'CA', 91950, 'apartment', '2', 'Y', 'N', 1100, 225, 1033, 538, Decimal('0.5808'), 'ST490', 'R6'),
#  ('W20', 'L4761', 'Chicago', 'IL', 60607, 'apartment', '1', 'Y', 'N', 1700, 106, 465, 312, Decimal('0.4110'), 'ST20', 'R2'),
#  ('W200', 'L1902', 'San Diego', 'CA', 92118, 'house', '2', 'Y', 'N', 3600, 336, 624, 491, Decimal('0.3973'), 'ST200', 'R14'),
#  ('W201', 'L1916', 'San Diego', 'CA', 92154, 'apartment', '1', 'Y', 'N', 1200, 173, 395, 204, Decimal('0.7973'), 'ST201', 'R2'),
#  ('W202', 'L1916', 'San Diego', 'CA', 92154, 'apartment', '2', 'Y', 'N', 1600, 228, 456, 245, Decimal('0.6877'), 'ST202', 'R6'),
#  ('W203', 'L1916', 'San Diego', 'CA', 92154, 'house', '1', 'Y', 'N', 1000, 155, 252, 197, Decimal('0.5890'), 'ST203', 'R10'),
#  ('W204', 'L1916', 'San Diego', 'CA', 92154, 'house', '2', 'Y', 'N', 1500, 158, 236, 195, Decimal('0.6192'), 'ST204', 'R14'),
#  ('W205', 'L12252', 'Columbus', 'OH', 43201, 'apartment', '1', 'Y', 'N', 750, 89, 155, 124, Decimal('0.4548'), 'ST205', 'R2'),
#  ('W206', 'L12252', 'Columbus', 'OH', 43201, 'apartment', '2', 'Y', 'N', 1040, 115, 179, 156, Decimal('0.4877'), 'ST206', 'R6'),
#  ('W207', 'L12252', 'Columbus', 'OH', 43201, 'house', '1', 'Y', 'N', 900, 152, 300, 256, Decimal('0.4795'), 'ST207', 'R10'),
#  ('W208', 'L12252', 'Columbus', 'OH', 43201, 'house', '2', 'Y', 'N', 1400, 175, 368, 284, Decimal('0.4932'), 'ST208', 'R14'),
#  ('W209', 'L12260', 'Columbus', 'OH', 43212, 'apartment', '1', 'Y', 'N', 825, 77, 161, 128, Decimal('0.3616'), 'ST209', 'R2'),
#  ('W21', 'L4765', 'Chicago', 'IL', 60611, 'apartment', '2', 'Y', 'N', 2700, 157, 526, 337, Decimal('0.4219'), 'ST21', 'R6'),
#  ('W210', 'L12260', 'Columbus', 'OH', 43212, 'apartment', '2', 'Y', 'N', 1300, 125, 170, 139, Decimal('0.7425'), 'ST210', 'R6'),
#  ('W211', 'L12260', 'Columbus', 'OH', 43212, 'house', '1', 'Y', 'N', 1000, 140, 288, 240, Decimal('0.3699'), 'ST211', 'R10'),
#  ('W218', 'L16888', 'Richmond', 'VA', 23113, 'apartment', '2', 'Y', 'N', 1200, 125, 277, 203, Decimal('0.2712'), 'ST218', 'R6'),
#  ('W219', 'L16888', 'Richmond', 'VA', 23113, 'house', '1', 'Y', 'N', 1400, 209, 384, 240, Decimal('0.7616'), 'ST219', 'R10'),
#  ('W220', 'L16888', 'Richmond', 'VA', 23113, 'house', '2', 'Y', 'N', 1600, 220, 418, 312, Decimal('0.6082'), 'ST220', 'R14'),
#  ('W221', 'L16887', 'Richmond', 'VA', 23060, 'apartment', '1', 'Y', 'N', 1105, 82, 235, 111, Decimal('0.6110'), 'ST221', 'R2'),
#  ('W222', 'L16887', 'Richmond', 'VA', 23060, 'apartment', '2', 'Y', 'N', 1665, 130, 200, 169, Decimal('0.3068'), 'ST222', 'R6'),
#  ('W223', 'L16887', 'Richmond', 'VA', 23060, 'house', '1', 'Y', 'N', 1175, 106, 267, 201, Decimal('0.5233'), 'ST223', 'R10'),
#  ('W224', 'L16887', 'Richmond', 'VA', 23060, 'house', '2', 'Y', 'N', 1725, 195, 305, 242, Decimal('0.4822'), 'ST224', 'R14'),
#  ('W225', 'L16898', 'Richmond', 'VA', 23234, 'apartment', '1', 'Y', 'N', 709, 86, 192, 158, Decimal('0.2219'), 'ST225', 'R2'),
#  ('W226', 'L16898', 'Richmond', 'VA', 23234, 'apartment', '2', 'Y', 'N', 869, 135, 305, 246, Decimal('0.3890'), 'ST226', 'R6'),
#  ('W227', 'L16898', 'Richmond', 'VA', 23234, 'house', '1', 'Y', 'N', 925, 125, 288, 207, Decimal('0.4164'), 'ST227', 'R10'),
#  ('W228', 'L16898', 'Richmond', 'VA', 23234, 'house', '2', 'Y', 'N', 1350, 119, 360, 224, Decimal('0.4849'), 'ST228', 'R14'),
#  ('W229', 'L16890', 'Richmond', 'VA', 23220, 'apartment', '1', 'Y', 'N', 900, 89, 177, 139, Decimal('0.5507'), 'ST229', 'R2'),
#  ('W230', 'L16890', 'Richmond', 'VA', 23220, 'apartment', '2', 'Y', 'N', 1325, 161, 319, 283, Decimal('0.2932'), 'ST230', 'R6'),
#  ('W231', 'L16890', 'Richmond', 'VA', 23220, 'house', '1', 'Y', 'N', 975, 145, 300, 192, Decimal('0.5014'), 'ST231', 'R10'),
#  ('W232', 'L16890', 'Richmond', 'VA', 23220, 'house', '2', 'Y', 'N', 1550, 185, 376, 307, Decimal('0.3014'), 'ST232', 'R14'),
#  ('W235', 'L14416', 'Charleston', 'SC', 29438, 'house', '1', 'Y', 'N', 1400, 135, 287, 232, Decimal('0.4986'), 'ST235', 'R10'),
#  ('W236', 'L14416', 'Charleston', 'SC', 29438, 'house', '2', 'Y', 'N', 1995, 224, 331, 292, Decimal('0.6384'), 'ST236', 'R14'),
#  ('W237', 'L14418', 'Charleston', 'SC', 29470, 'apartment', '1', 'Y', 'N', 760, 100, 195, 169, Decimal('0.2904'), 'ST237', 'R2'),
#  ('W238', 'L14418', 'Charleston', 'SC', 29470, 'apartment', '2', 'Y', 'N', 965, 135, 284, 189, Decimal('0.5397'), 'ST238', 'R6'),
#  ('W239', 'L14418', 'Charleston', 'SC', 29470, 'house', '1', 'Y', 'N', 1185, 157, 320, 289, Decimal('0.2795'), 'ST239', 'R10'),
#  ('W240', 'L14418', 'Charleston', 'SC', 29470, 'house', '2', 'Y', 'N', 1340, 135, 347, 278, Decimal('0.3890'), 'ST240', 'R14'),
#  ('W241', 'L14419', 'Charleston', 'SC', 29487, 'apartment', '1', 'Y', 'N', 1150, 80, 267, 183, Decimal('0.5753'), 'ST241', 'R2'),
#  ('W242', 'L14419', 'Charleston', 'SC', 29487, 'apartment', '2', 'Y', 'N', 2000, 160, 323, 237, Decimal('0.3123'), 'ST242', 'R6'),
#  ('W243', 'L14419', 'Charleston', 'SC', 29487, 'house', '1', 'Y', 'N', 1600, 225, 406, 297, Decimal('0.4521'), 'ST243', 'R10'),
#  ('W244', 'L14419', 'Charleston', 'SC', 29487, 'house', '2', 'Y', 'N', 2150, 170, 447, 360, Decimal('0.5315'), 'ST244', 'R14'),
#  ('W3', 'L9531', 'Chapel Hill', 'NC', 27514, 'house', '2', 'Y', 'N', 2000, 97, 240, 199, Decimal('0.3123'), 'ST3', 'R14'),
#  ('W22', 'L4765', 'Chicago', 'IL', 60611, 'house', '1', 'Y', 'N', 2700, 202, 629, 389, Decimal('0.5123'), 'ST422', 'R10'),
#  ('W23', 'L4765', 'Chicago', 'IL', 60611, 'house', '2', 'Y', 'N', 3200, 195, 844, 325, Decimal('0.8164'), 'ST423', 'R14'),
#  ('W24', 'L4765', 'Chicago', 'IL', 60611, 'apartment', '1', 'Y', 'N', 1700, 98, 430, 239, Decimal('0.6767'), 'ST424', 'R2'),
#  ('W25', 'L4770', 'Chicago', 'IL', 60616, 'apartment', '1', 'Y', 'N', 1600, 94, 411, 209, Decimal('0.5397'), 'ST425', 'R2'),
#  ('W26', 'L4770', 'Chicago', 'IL', 60616, 'apartment', '2', 'Y', 'N', 2100, 130, 438, 265, Decimal('0.4027'), 'ST426', 'R6'),
#  ('W27', 'L4770', 'Chicago', 'IL', 60616, 'house', '1', 'Y', 'N', 1200, 162, 504, 435, Decimal('0.4000'), 'ST427', 'R10'),
#  ('W28', 'L4770', 'Chicago', 'IL', 60616, 'house', '2', 'Y', 'N', 2100, 175, 755, 487, Decimal('0.4301'), 'ST428', 'R14'),
#  ('W29', 'L4794', 'Chicago', 'IL', 60642, 'apartment', '2', 'Y', 'N', 2500, 129, 431, 231, Decimal('0.4027'), 'ST429', 'R6'),
#  ('W212', 'L12260', 'Columbus', 'OH', 43212, 'house', '2', 'Y', 'N', 1480, 175, 310, 249, Decimal('0.4411'), 'ST512', 'R14'),
#  ('W213', 'L12264', 'Columbus', 'OH', 43222, 'apartment', '1', 'Y', 'N', 650, 80, 156, 107, Decimal('0.4795'), 'ST513', 'R2'),
#  ('W214', 'L12264', 'Columbus', 'OH', 43222, 'apartment', '2', 'Y', 'N', 920, 108, 205, 147, Decimal('0.4137'), 'ST514', 'R6'),
#  ('W215', 'L12264', 'Columbus', 'OH', 43222, 'house', '1', 'Y', 'N', 880, 145, 333, 246, Decimal('0.4438'), 'ST515', 'R10'),
#  ('W216', 'L12264', 'Columbus', 'OH', 43222, 'house', '2', 'Y', 'N', 1200, 160, 310, 169, Decimal('0.6192'), 'ST516', 'R14'),
#  ('W217', 'L16888', 'Richmond', 'VA', 23113, 'apartment', '1', 'Y', 'N', 1000, 95, 280, 174, Decimal('0.5479'), 'ST517', 'R2'),
#  ('W233', 'L14416', 'Charleston', 'SC', 29438, 'apartment', '1', 'Y', 'N', 1165, 135, 220, 180, Decimal('0.3425'), 'ST519', 'R2'),
#  ('W234', 'L14416', 'Charleston', 'SC', 29438, 'apartment', '2', 'Y', 'N', 1625, 220, 312, 260, Decimal('0.6000'), 'ST520', 'R6'),
#  ('W31', 'L4794', 'Chicago', 'IL', 60642, 'house', '2', 'Y', 'N', 2750, 188, 810, 538, Decimal('0.6000'), 'ST31', 'R14'),
#  ('W32', 'L4794', 'Chicago', 'IL', 60642, 'apartment', '1', 'Y', 'N', 1800, 89, 390, 288, Decimal('0.2329'), 'ST32', 'R2'),
#  ('W33', 'L4804', 'Chicago', 'IL', 60654, 'apartment', '2', 'Y', 'N', 3000, 193, 648, 415, Decimal('0.4082'), 'ST33', 'R6'),
#  ('W34', 'L4804', 'Chicago', 'IL', 60654, 'house', '1', 'Y', 'N', 2000, 193, 600, 387, Decimal('0.3260'), 'ST34', 'R10'),
#  ('W35', 'L4804', 'Chicago', 'IL', 60654, 'house', '2', 'Y', 'N', 2950, 192, 829, 575, Decimal('0.3890'), 'ST35', 'R14'),
#  ('W55', 'L11480', 'New York', 'NY', 11101, 'house', '2', 'Y', 'N', 3000, 195, 752, 620, Decimal('0.2932'), 'ST355', 'R14'),
#  ('W56', 'L11480', 'New York', 'NY', 11101, 'apartment', '1', 'Y', 'N', 3000, 80, 469, 235, Decimal('0.6411'), 'ST356', 'R2'),
#  ('W57', 'L11495', 'New York', 'NY', 11211, 'apartment', '2', 'Y', 'N', 3900, 116, 361, 284, Decimal('0.5041'), 'ST357', 'R6'),
#  ('W58', 'L11495', 'New York', 'NY', 11211, 'house', '1', 'Y', 'N', 2800, 102, 799, 355, Decimal('0.4027'), 'ST358', 'R10'),
#  ('W59', 'L11495', 'New York', 'NY', 11211, 'house', '2', 'Y', 'N', 3500, 188, 724, 436, Decimal('0.5068'), 'ST359', 'R14'),
#  ('W36', 'L4804', 'Chicago', 'IL', 60654, 'apartment', '1', 'Y', 'N', 1700, 98, 432, 228, Decimal('0.5205'), 'ST36', 'R2'),
#  ('W60', 'L11495', 'New York', 'NY', 11211, 'apartment', '1', 'Y', 'N', 2600, 69, 406, 250, Decimal('0.3699'), 'ST360', 'R2'),
#  ('W61', 'L1734', 'Palo Alto', 'CA', 94025, 'apartment', '2', 'Y', 'N', 2695, 265, 534, 443, Decimal('0.2356'), 'ST361', 'R6'),
#  ('W62', 'L1734', 'Palo Alto', 'CA', 94025, 'house', '1', 'Y', 'N', 3000, 158, 706, 343, Decimal('0.5808'), 'ST362', 'R10'),
#  ('W63', 'L1734', 'Palo Alto', 'CA', 94025, 'house', '2', 'Y', 'N', 4000, 306, 781, 739, Decimal('0.0192'), 'ST363', 'R14'),
#  ('W64', 'L1734', 'Palo Alto', 'CA', 94025, 'apartment', '1', 'Y', 'N', 2295, 100, 469, 270, Decimal('0.4685'), 'ST364', 'R2'),
#  ('W65', 'L1735', 'Palo Alto', 'CA', 94301, 'apartment', '2', 'Y', 'N', 3000, 270, 543, 424, Decimal('0.3425'), 'ST365', 'R6'),
#  ('W66', 'L1735', 'Palo Alto', 'CA', 94301, 'house', '1', 'Y', 'N', 3300, 283, 1261, 980, Decimal('0.2712'), 'ST366', 'R10'),
#  ('W37', 'L11419', 'New York', 'NY', 10002, 'apartment', '1', 'Y', 'N', 3000, 87, 512, 337, Decimal('0.4630'), 'ST37', 'R2'),
#  ('W38', 'L11419', 'New York', 'NY', 10002, 'apartment', '2', 'Y', 'N', 3200, 154, 480, 154, Decimal('0.6795'), 'ST38', 'R6'),
#  ('W39', 'L11421', 'New York', 'NY', 10004, 'apartment', '2', 'Y', 'N', 4500, 273, 853, 432, Decimal('0.6822'), 'ST39', 'R6'),
#  ('W4', 'L9531', 'Chapel Hill', 'NC', 27514, 'apartment', '1', 'Y', 'N', 800, 53, 188, 104, Decimal('0.5699'), 'ST4', 'R2'),
#  ('W40', 'L11421', 'New York', 'NY', 10004, 'house', '1', 'Y', 'N', 4500, 103, 807, 200, Decimal('0.8685'), 'ST40', 'R10'),
#  ('W41', 'L11421', 'New York', 'NY', 10004, 'house', '2', 'Y', 'N', 5500, 200, 770, 428, Decimal('0.5233'), 'ST41', 'R14'),
#  ('W42', 'L11421', 'New York', 'NY', 10004, 'apartment', '1', 'Y', 'N', 3500, 151, 890, 576, Decimal('0.4603'), 'ST42', 'R2'),
#  ('W43', 'L11427', 'New York', 'NY', 10014, 'apartment', '2', 'Y', 'N', 4000, 218, 681, 560, Decimal('0.3534'), 'ST43', 'R6'),
#  ('W30', 'L4794', 'Chicago', 'IL', 60642, 'house', '1', 'Y', 'N', 2500, 186, 578, 490, Decimal('0.2301'), 'ST430', 'R10'),
#  ('W44', 'L11427', 'New York', 'NY', 10014, 'apartment', '1', 'Y', 'N', 3000, 109, 640, 288, Decimal('0.4986'), 'ST44', 'R2'),
#  ('W45', 'L11431', 'New York', 'NY', 10019, 'apartment', '2', 'Y', 'N', 5600, 196, 612, 373, Decimal('0.5151'), 'ST45', 'R6'),
#  ('W46', 'L11431', 'New York', 'NY', 10019, 'house', '1', 'Y', 'N', 3200, 165, 1296, 420, Decimal('0.8712'), 'ST46', 'R10'),
#  ('W47', 'L11431', 'New York', 'NY', 10019, 'house', '2', 'Y', 'N', 3500, 268, 1032, 593, Decimal('0.5068'), 'ST47', 'R14'),
#  ('W48', 'L11431', 'New York', 'NY', 10019, 'apartment', '1', 'Y', 'N', 3400, 106, 624, 436, Decimal('0.2822'), 'ST48', 'R2'),
#  ('W49', 'L11434', 'New York', 'NY', 10023, 'apartment', '2', 'Y', 'N', 4200, 210, 654, 426, Decimal('0.5425'), 'ST49', 'R6'),
#  ('W5', 'L9532', 'Chapel Hill', 'NC', 27516, 'apartment', '2', 'Y', 'N', 1100, 111, 148, 142, Decimal('0.0822'), 'ST5', 'R6'),
#  ('W50', 'L11434', 'New York', 'NY', 10023, 'house', '1', 'Y', 'N', 3000, 133, 1040, 621, Decimal('0.3479'), 'ST50', 'R10'),
#  ('W51', 'L11434', 'New York', 'NY', 10023, 'house', '2', 'Y', 'N', 3900, 231, 888, 535, Decimal('0.4767'), 'ST51', 'R14'),
#  ('W52', 'L11434', 'New York', 'NY', 10023, 'apartment', '1', 'Y', 'N', 3600, 137, 808, 196, Decimal('0.7781'), 'ST52', 'R2'),
#  ('W53', 'L11480', 'New York', 'NY', 11101, 'apartment', '2', 'Y', 'N', 3500, 155, 483, 294, Decimal('0.3973'), 'ST53', 'R6'),
#  ('W54', 'L11480', 'New York', 'NY', 11101, 'house', '1', 'Y', 'N', 2500, 111, 868, 471, Decimal('0.6000'), 'ST54', 'R10'),
#  ('W6', 'L9532', 'Chapel Hill', 'NC', 27516, 'house', '1', 'Y', 'N', 900, 116, 296, 141, Decimal('0.5479'), 'ST6', 'R10'),
#  ('W67', 'L1735', 'Palo Alto', 'CA', 94301, 'house', '2', 'Y', 'N', 4500, 530, 1354, 994, Decimal('0.4301'), 'ST67', 'R14'),
#  ('W68', 'L1735', 'Palo Alto', 'CA', 94301, 'apartment', '1', 'Y', 'N', 2700, 103, 483, 284, Decimal('0.6055'), 'ST68', 'R2'),
#  ('W69', 'L1736', 'Palo Alto', 'CA', 94303, 'apartment', '1', 'Y', 'N', 2700, 110, 515, 236, Decimal('0.5671'), 'ST69', 'R2'),
#  ('W7', 'L9532', 'Chapel Hill', 'NC', 27516, 'house', '2', 'Y', 'N', 1100, 136, 335, 188, Decimal('0.6192'), 'ST7', 'R14'),
#  ('W70', 'L1736', 'Palo Alto', 'CA', 94303, 'apartment', '2', 'Y', 'N', 3000, 270, 544, 329, Decimal('0.7041'), 'ST70', 'R6'),
#  ('W71', 'L1736', 'Palo Alto', 'CA', 94303, 'house', '1', 'Y', 'N', 4500, 231, 1027, 549, Decimal('0.4438'), 'ST71', 'R10'),
#  ('W72', 'L1736', 'Palo Alto', 'CA', 94303, 'house', '2', 'Y', 'N', 4900, 379, 969, 652, Decimal('0.4466'), 'ST72', 'R14'),
#  ('W73', 'L1737', 'Palo Alto', 'CA', 94305, 'apartment', '2', 'Y', 'N', 3300, 264, 532, 378, Decimal('0.4219'), 'ST73', 'R6'),
#  ('W74', 'L1737', 'Palo Alto', 'CA', 94305, 'house', '1', 'Y', 'N', 4500, 151, 673, 255, Decimal('0.5918'), 'ST74', 'R10'),
#  ('W75', 'L1737', 'Palo Alto', 'CA', 94305, 'house', '2', 'Y', 'N', 4200, 278, 711, 441, Decimal('0.5726'), 'ST75', 'R14'),
#  ('W76', 'L1737', 'Palo Alto', 'CA', 94305, 'apartment', '1', 'Y', 'N', 2500, 98, 460, 356, Decimal('0.4247'), 'ST76', 'R2'),
#  ('W77', 'L1738', 'Palo Alto', 'CA', 94306, 'apartment', '1', 'Y', 'N', 2500, 108, 507, 437, Decimal('0.0795'), 'ST77', 'R2'),
#  ('W78', 'L1738', 'Palo Alto', 'CA', 94306, 'apartment', '2', 'Y', 'N', 3300, 270, 543, 461, Decimal('0.3178'), 'ST78', 'R6'),
#  ('W79', 'L1738', 'Palo Alto', 'CA', 94306, 'house', '1', 'Y', 'N', 4500, 186, 829, 669, Decimal('0.3123'), 'ST79', 'R10'),
#  ('W8', 'L9532', 'Chapel Hill', 'NC', 27516, 'apartment', '1', 'Y', 'N', 500, 50, 174, 121, Decimal('0.3973'), 'ST8', 'R2'),
#  ('W80', 'L1738', 'Palo Alto', 'CA', 94306, 'house', '2', 'Y', 'N', 4200, 319, 815, 437, Decimal('0.6110'), 'ST80', 'R14'),
#  ('W81', 'L1940', 'San Francisco', 'CA', 94103, 'apartment', '2', 'Y', 'N', 3600, 332, 805, 663, Decimal('0.2329'), 'ST81', 'R6'),
#  ('W82', 'L1940', 'San Francisco', 'CA', 94103, 'house', '1', 'Y', 'N', 4000, 179, 629, 337, Decimal('0.5068'), 'ST82', 'R10'),
#  ('W83', 'L1940', 'San Francisco', 'CA', 94103, 'house', '2', 'Y', 'N', 5500, 227, 813, 447, Decimal('0.6164'), 'ST83', 'R14'),
#  ('W84', 'L1940', 'San Francisco', 'CA', 94103, 'apartment', '1', 'Y', 'N', 3000, 115, 650, 610, Decimal('0.1014'), 'ST84', 'R2'),
#  ('W85', 'L1941', 'San Francisco', 'CA', 94110, 'apartment', '2', 'Y', 'N', 4000, 220, 534, 302, Decimal('0.3151'), 'ST85', 'R6'),
#  ('W86', 'L1941', 'San Francisco', 'CA', 94110, 'house', '1', 'Y', 'N', 4000, 128, 450, 213, Decimal('0.6521'), 'ST86', 'R10'),
#  ('W87', 'L1941', 'San Francisco', 'CA', 94110, 'house', '2', 'Y', 'N', 5000, 152, 546, 364, Decimal('0.5123'), 'ST87', 'R14'),
#  ('W88', 'L1941', 'San Francisco', 'CA', 94110, 'apartment', '1', 'Y', 'N', 3200, 94, 528, 251, Decimal('0.6274'), 'ST88', 'R2'),
#  ('W89', 'L1942', 'San Francisco', 'CA', 94112, 'apartment', '2', 'Y', 'N', 3500, 194, 471, 343, Decimal('0.3973'), 'ST89', 'R6'),
#  ('W9', 'L9533', 'Chapel Hill', 'NC', 27517, 'apartment', '1', 'Y', 'N', 965, 50, 174, 125, Decimal('0.3753'), 'ST9', 'R2'),
#  ('W90', 'L1942', 'San Francisco', 'CA', 94112, 'house', '1', 'Y', 'N', 3200, 138, 485, 251, Decimal('0.3342'), 'ST90', 'R10'),
#  ('W91', 'L1942', 'San Francisco', 'CA', 94112, 'house', '2', 'Y', 'N', 3500, 152, 547, 404, Decimal('0.3616'), 'ST91', 'R14'),
#  ('W92', 'L1942', 'San Francisco', 'CA', 94112, 'apartment', '1', 'Y', 'N', 3000, 77, 432, 161, Decimal('0.2658'), 'ST92', 'R2'),
#  ('W93', 'L1943', 'San Francisco', 'CA', 94118, 'apartment', '1', 'Y', 'N', 2600, 100, 565, 408, Decimal('0.3863'), 'ST93', 'R2'),
#  ('W94', 'L1943', 'San Francisco', 'CA', 94118, 'apartment', '2', 'Y', 'N', 4000, 204, 494, 284, Decimal('0.3151'), 'ST94', 'R6'),
#  ('W95', 'L1943', 'San Francisco', 'CA', 94118, 'house', '1', 'Y', 'N', 4000, 257, 903, 443, Decimal('0.5562'), 'ST95', 'R10'),
#  ('W96', 'L1943', 'San Francisco', 'CA', 94118, 'house', '2', 'Y', 'N', 5100, 256, 916, 718, Decimal('0.4493'), 'ST96', 'R14'),
#  ('W97', 'L1944', 'San Francisco', 'CA', 94129, 'apartment', '2', 'Y', 'N', 5600, 265, 644, 478, Decimal('0.3178'), 'ST97', 'R6'),
#  ('W98', 'L1944', 'San Francisco', 'CA', 94129, 'house', '1', 'Y', 'N', 5000, 236, 829, 533, Decimal('0.5123'), 'ST98', 'R10'),
#  ('W99', 'L1944', 'San Francisco', 'CA', 94129, 'house', '2', 'Y', 'N', 6000, 244, 872, 566, Decimal('0.3699'), 'ST99', 'R14')]
